# %%
#imports and load data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('winequality_edited.csv')

# %%
df
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
df.shape[0]# gives number of row count
df.shape[1]  # gives number of col count
df.shape
# Out:
# (6497, 14)

# %%
df.describe().pH
# Out:
# count    6497.000000
# mean        3.218501
# std         0.160787
# min         2.720000
# 25%         3.110000
# 50%         3.210000
# 75%         3.320000
# max         4.010000
# Name: pH, dtype: float64

# %%
bin_edges = [2.72, 3.11, 3.21, 3.32, 4.01]

# %%
bin_names = ['high', 'mod_high', 'medium', 'low']
df['acidity_levels']=pd.cut(df['pH'], bin_edges, labels = bin_names)

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color acidity_levels
# 0      9.4        5   red            low
# ...

# %%
df.describe().alcohol
# Out:
# count    6497.000000
# mean       10.491801
# std         1.192712
# min         8.000000
# 25%         9.500000
# 50%        10.300000
# 75%        11.300000
# max        14.900000
# Name: alcohol, dtype: float64

# %%
 #Low alcohol (samples with an alcohol content less than the median)
#filter_low =df.query('alcohol <10.3',inplace = True)
low_alcohol = df.query('alcohol < 10.3',inplace = True)

# %%
low_alcohol

# %%
# High alcohol (samples with an alcohol content greater than or equal to the median)
high_alcohol = df.query('alcohol >= 10.3',inplace = True)

# %%
#num_samples = df.shape[0] # return the number of row
len(df)

#num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count() # should be True
# Out:
# 0

# %%
num_samples = df.shape[0] # return the number of row 
num_samples
# Out:
# 6497

# %%
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-b1dd70ef5f08> in <module>
# ----> 1 num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count()
#
# TypeError: 'NoneType' object is not subscriptable
